# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
import requests
import datetime
from bs4 import BeautifulSoup
from PIL import Image
import cv2

# %%
url = 'https://pportal.hpa.gov.tw/Web/Notice.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.maximize_window()
time.sleep(1)
driver.find_element('xpath','//*[@id="ctl00_pnlLogin"]/button').click()
time.sleep(1)
print("網址設定成功")
for i in range(1,21):
    driver.save_screenshot('screen.jpg')
    element =driver.find_element('xpath','//*[@id="imgCheckCode"]')
    left = element.location['x']
    top = element.location['y']
    right = left + element.size['width']
    bottom = top + element.size['height']
    img  = Image.open('screen.jpg')
    img = img.crop((left, top, right, bottom))
    img = img.convert("RGB")
    img.save('numbercheck.jpg', 'jpeg')
    img = img.convert("L")  # 將圖片轉成灰階
    pix_img = img.load()
    w, h = img.size
    threshold = 205 #像素閥值
    for y in range(h):    #for迴圈將每個像素點進行判斷
        for x in range(w):
            if pix_img[x, y] < threshold:
                pix_img[x, y] = 0
            else:
                pix_img[x, y] = 255
    data = img.getdata()
    w, h = img.size
    black_point = 0
    for x in range(1, w - 1):
        for y in range(1, h - 1):
            mid_pixel = data[w * y + x]
            if mid_pixel < 50:
                top_pixel = data[w * (y - 1) + x]
                left_pixel = data[w * y + (x - 1)]
                down_pixel = data[w * (y + 1) + x]
                right_pixel = data[w * y + (x + 1)]
                if top_pixel < 10:
                    black_point += 1
                if left_pixel < 10:
                    black_point += 1
                if down_pixel < 10:
                    black_point += 1
                if right_pixel < 10:
                    black_point += 1
                if black_point < 1:
                    img.putpixel((x, y), 255)
                black_point = 0
    driver.find_element('xpath','//*[@id="btnRefreshCode"]').click()
    img.save(f'C:/Users/dl/Desktop/yc_data/babyCrawler/CaptchaJpg/Train/{i}.jpg')
    print(f"已儲存:{i}.jpg")
driver.quit()
# Out:
# C:\Users\dl\AppData\Local\Temp\ipykernel_18744\3589982021.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 網址設定成功
# C:\ProgramData\anaconda3\envs\myenv\lib\site-packages\selenium\webdriver\remote\webdriver.py:889: UserWarning: name used for saved screenshot does not match file type. It should end with a `.png` extension
#   warnings.warn(
# 已儲存:1.jpg
# 已儲存:2.jpg
# 已儲存:3.jpg
# 已儲存:4.jpg
# 已儲存:5.jpg
# 已儲存:6.jpg
# 已儲存:7.jpg
# 已儲存:8.jpg
# 已儲存:9.jpg
# 已儲存:10.jpg
# 已儲存:11.jpg
# 已儲存:12.jpg
# 已儲存:13.jpg
# 已儲存:14.jpg
# 已儲存:15.jpg
# 已儲存:16.jpg
# 已儲存:17.jpg
# 已儲存:18.jpg
# 已儲存:19.jpg
# 已儲存:20.jpg

# %%
url = 'https://pportal.hpa.gov.tw/Web/Notice.aspx'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.maximize_window()
time.sleep(1)
driver.find_element('xpath','//*[@id="ctl00_pnlLogin"]/button').click()
time.sleep(1)
print("網址設定成功")
for i in range(1,201):
    driver.save_screenshot('screen.jpg')
    element =driver.find_element('xpath','//*[@id="imgCheckCode"]')
    left = element.location['x']
    top = element.location['y']
    right = left + element.size['width']
    bottom = top + element.size['height']
    img  = Image.open('screen.jpg')
    img = img.crop((left, top, right, bottom))
    img = img.convert("RGB")
    img.save('numbercheck.jpg', 'jpeg')
    img = img.convert("L")  # 將圖片轉成灰階
    pix_img = img.load()
    w, h = img.size
    threshold = 205 #像素閥值
    for y in range(h):    #for迴圈將每個像素點進行判斷
        for x in range(w):
            if pix_img[x, y] < threshold:
                pix_img[x, y] = 0
            else:
                pix_img[x, y] = 255
    data = img.getdata()
    w, h = img.size
    black_point = 0
    for x in range(1, w - 1):
        for y in range(1, h - 1):
            mid_pixel = data[w * y + x]
            if mid_pixel < 50:
                top_pixel = data[w * (y - 1) + x]
                left_pixel = data[w * y + (x - 1)]
                down_pixel = data[w * (y + 1) + x]
                right_pixel = data[w * y + (x + 1)]
                if top_pixel < 10:
                    black_point += 1
                if left_pixel < 10:
                    black_point += 1
                if down_pixel < 10:
                    black_point += 1
                if right_pixel < 10:
                    black_point += 1
                if black_point < 1:
                    img.putpixel((x, y), 255)
                black_point = 0
    driver.find_element('xpath','//*[@id="btnRefreshCode"]').click()
    img.save(f'C:/Users/dl/Desktop/yc_data/babyCrawler/CaptchaJpg/Test/{i}.jpg')
    print(f"已儲存:{i}.jpg")
driver.quit()
# Out:
# C:\Users\dl\AppData\Local\Temp\ipykernel_19136\2908390489.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 網址設定成功
# 已儲存:1.jpg
# 已儲存:2.jpg
# 已儲存:3.jpg
# 已儲存:4.jpg
# 已儲存:5.jpg
# 已儲存:6.jpg
# 已儲存:7.jpg
# 已儲存:8.jpg
# 已儲存:9.jpg
# 已儲存:10.jpg
# 已儲存:11.jpg
# 已儲存:12.jpg
# 已儲存:13.jpg
# 已儲存:14.jpg
# 已儲存:15.jpg
# 已儲存:16.jpg
# 已儲存:17.jpg
# 已儲存:18.jpg
# 已儲存:19.jpg
# 已儲存:20.jpg
# 已儲存:21.jpg
# 已儲存:22.jpg
# 已儲存:23.jpg
# 已儲存:24.jpg
# 已儲存:25.jpg
# 已儲存:26.jpg
# 已儲存:27.jpg
# 已儲存:28.jpg
# 已儲存:29.jpg
# 已儲存:30.jpg
# 已儲存:31.jpg
# 已儲存:32.jpg
# 已儲存:33.jpg
# 已儲存:34.jpg
# 已儲存:35.jpg
# 已儲存:36.jpg
# 已儲存:37.jpg
# 已儲存:38.jpg
# 已儲存:39.jpg
# 已儲存:40.jpg
# 已儲存:41.jpg
# 已儲存:42.jpg
# 已儲存:43.jpg
# 已儲存:44.jpg
# 已儲存:45.jpg
# 已儲存:46.jpg
# 已儲存:47.jpg
# 已儲存:48.jpg
# 已儲存:49.jpg
# 已儲存:50.jpg
# 已儲存:51.jpg
# 已儲存:52.jpg
# 已儲存:53.jpg
# 已儲存:54.jpg
# 已儲存:55.jpg
# 已儲存:56.jpg
# 已儲存:57.jpg
# 已儲存:58.jpg
# 已儲存:59.jpg
# 已儲存:60.jpg
# 已儲存:61.jpg
# 已儲存:62.jpg
# 已儲存:63.jpg
# 已儲存:64.jpg
# 已儲存:65.jpg
# 已儲存:66.jpg
# 已儲存:67.jpg
# 已儲存:68.jpg
# 已儲存:69.jpg
# 已儲存:70.jpg
# 已儲存:71.jpg
# 已儲存:72.jpg
# 已儲存:73.jpg
# 已儲存:74.jpg
# 已儲存:75.jpg
# 已儲存:76.jpg
# 已儲存:77.jpg
# 已儲存:78.jpg
